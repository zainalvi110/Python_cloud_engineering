# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./dataset/titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[data['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#describe (min ,max ,mean,mode,)
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.shape
# Out:
# (891, 12)

# %%
data.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
data.columns  #will bring out the name of columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
data.sort_values(by='Survived',ascending= False, na_position='first')
# Out:
#      PassengerId  Survived  Pclass  \
# 445          446         1       1
# 319          320         1       1
# 334          335         1       1
# 330          331         1       3
# 329          330         1       1
# ..           ...       ...     ...
# 365          366         0       3
# 371          372         0       3
# 372          373         0       3
# 373          374         0       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 445                          Dodge, Master. Washington    male   4.0      0
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...  female   NaN      1
# 330                                 McCoy, Miss. Agnes  female   NaN      2
# 329                       Hippach, Miss. Jean Gertrude  female  16.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[['Age','Name']]
data['Age'] > 25
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
data['Age']>25
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
data['Age'] > 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 data['Age'] > 20
#
# TypeError: list indices must be integers or slices, not str

# %%
data[data['Age']> 30]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 data[data['Age']> 30]
#
# TypeError: list indices must be integers or slices, not str

# %%
data[data['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data[data ['Pclass']== 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
first_class=data ['Pclass']== 1
sex= data['Sex']=='male'
data[first_class &sex]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
data[data['Pclass'].isin([2,1])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Body_founded']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Body_founded'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 data['Body_founded']
#
# ...

# %%
data['Discounted_fare']=data['Fare']/5
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv('./dataset/titanic.csv')  # Replace with your CSV file name

# Calculate the discounted fare
def calculate_discounted_fare(row):
    fare = row['Fare']
    age = row['Age']
    if age < 20:
        return fare - (fare / 20)  # 5% discount
    elif 20 <= age <= 30:
        return fare - (fare / 30)  # 3.33% discount
    else:
        return fare  # No discount

# Apply the discount calculation to each row
data['Discounted_Fare'] = data.apply(calculate_discounted_fare, axis=1)

data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv("./dataset/titanic.csv")  # Replace with your CSV file name
def calculate_discounted_fare(row):
    Fare = row['Fare']
    Age = row['Age']
    
    if Age < 20:
        return Fare - (Fare / 20)  # 5% discount
    elif 20 <= Age <= 30:
        return Fare - (Fare / 30)  # 3.33% discount
    else:
        return Fare  # No discount for other ages

# Apply the function to the dataframe
data['Discounted_Fare'] = data.apply(calculate_discounted_fare, axis=1)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv("./dataset/titanic.csv",index_col=0)  # Replace with your CSV file name
def age_increasing(row):
    Age = row['Age']
    Age =Age+5
    return Age
data['Age'] = data.apply(age_increasing, axis=1)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  27.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  43.0
# 3                                       Heikkinen, Miss. Laina  female  31.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  40.0
# 5                                     Allen, Mr. William Henry    male  40.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # lambda function

# %%
pd.DataFrame(data['Age'].cumsum())
# Out:
#                   Age
# PassengerId
# 1               27.00
# 2               70.00
# 3              101.00
# 4              141.00
# 5              181.00
# ...               ...
# 887          24683.17
# 888          24707.17
# 889               NaN
# 890          24738.17
# 891          24775.17
#
# [891 rows x 1 columns]

# %%
pd.DataFrame(data['Survived'].cumsum())
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   2
# 4                   3
# 5                   3
# ...               ...
# 887               340
# 888               341
# 889               341
# 890               342
# 891               342
#
# [891 rows x 1 columns]

# %%
pd.DataFrame(data['Age'].cummax())
# Out:
#               Age
# PassengerId
# 1            27.0
# 2            43.0
# 3            43.0
# 4            43.0
# 5            43.0
# ...           ...
# 887          85.0
# 888          85.0
# 889           NaN
# 890          85.0
# 891          85.0
#
# [891 rows x 1 columns]

# %%
data.drop_duplicates(subset='Pclass')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  27.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  43.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  19.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C
# 10               1      0     237736  30.0708   NaN        C

# %%
data.drop_duplicates(subset='Age')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 6                   0       3
# ...               ...     ...
# 756                 1       2
# 768                 0       3
# 804                 1       3
# 844                 0       3
# 852                 0       3
#
#                                                           Name     Sex    Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  27.00
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  43.00
# 3                                       Heikkinen, Miss. Laina  female  31.00
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  40.00
# 6                                             Moran, Mr. James    male    NaN
# ...                                                        ...     ...    ...
# ...

# %%
data.drop_duplicates(subset='Name')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  27.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  43.0
# 3                                       Heikkinen, Miss. Laina  female  31.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  40.0
# 5                                     Allen, Mr. William Henry    male  40.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ## pivot table

# %%
data.pivot_table(values='Age', 
                    index='Sex', 
                    columns='Survived',
                    fill_value=0,
                    margins=True,
                    margins_name='mean')
# Out:
# Survived          0          1       mean
# Sex
# female    30.046875  33.847716  32.915709
# male      36.618056  32.276022  35.726645
# mean      35.626179  33.343690  34.699118
